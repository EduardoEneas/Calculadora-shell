# %%
def calculadora():
    while True:
        print("Calculadora das 4 operações básicas: Qual operação iremos realizar?")
        print("1. Adição (+)")
        print("2. Subtração (-)")
        print("3. Multiplicação (*)")
        print("4. Divisão (/)")

        escolha = input("Digite o número da operação (1/2/3/4) ou 'sair' para encerrar: ")

        if escolha.lower() == 'sair':
            print("Saindo da calculadora...")
            break

        if escolha in ('1', '2', '3', '4'):
            try:
                num1 = float(input("Digite o primeiro número: "))
                num2 = float(input("Digite o segundo número: "))
            except ValueError:
                print("Por favor, insira números válidos.")
                continue

            if escolha == '1':
                resultado = num1 + num2
                operacao = 'adição'
            elif escolha == '2':
                resultado = num1 - num2
                operacao = 'subtração'
            elif escolha == '3':
                resultado = num1 * num2
                operacao = 'multiplicação'
            elif escolha == '4':
                if num2 != 0:
                    resultado = num1 / num2
                    operacao = 'divisão'
                else:
                    print("Erro: Divisão por zero não é permitida.")
                    continue

            print(f"O resultado da {operacao} entre {num1} e {num2} é: {resultado}")
        else:
            print("Escolha inválida. Tente novamente.")

calculadora()
# Out:
# Calculadora das 4 operações básicas: Qual operação iremos realizar?
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# O resultado da subtração entre 10.0 e 10.0 é: 0.0
# Calculadora das 4 operações básicas: Qual operação iremos realizar?
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# O resultado da subtração entre 20.0 e 13.0 é: 7.0
# Calculadora das 4 operações básicas: Qual operação iremos realizar?
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# O resultado da subtração entre 15.0 e 4.0 é: 11.0
# Calculadora das 4 operações básicas: Qual operação iremos realizar?
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# Escolha inválida. Tente novamente.
# Calculadora das 4 operações básicas: Qual operação iremos realizar?
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# Escolha inválida. Tente novamente.
# ...
